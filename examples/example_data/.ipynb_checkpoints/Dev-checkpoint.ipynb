# %%
# %config Completer.use_jedi = False
import csv
import io
import pandas as pd
import numpy as np
from typing import Union

# %%
sniff = csv.Sniffer()

# %%
file_path = '../../../Standard_Comparaison/Silane.csv'
with open(file_path, 'r') as f:
    print(f.encoding)
    dialect = sniff.sniff(f.read(4096), delimiters=';, \t')
    print(dialect)
data = pd.read_csv(file_path, dialect=dialect, encoding=f.encoding)
data['MatCode'] = data.MatCode.astype('Float64')
data.loc[6, 'MatCode'] = '*'
# Out:
# cp1252
# <class 'csv.Sniffer.sniff.<locals>.dialect'>

# %%
new_data = data.copy()

# %%
column_dtypes = data.dtypes

# %%
data.MatCode.map(type)
# Out:
# 0    <class 'float'>
# 1    <class 'float'>
# 2    <class 'float'>
# 3    <class 'float'>
# 4    <class 'float'>
# 5    <class 'float'>
# 6      <class 'str'>
# Name: MatCode, dtype: object

# %%
columns = pd.MultiIndex.from_tuples([(f'level_0_{i}', f'level_1_{j}', f'level_2_{k}') for i in range(2) for j in range(3) for k in range(5)])

# %%
columns = columns[np.random.randint(0, len(columns), size=len(columns))]

# %%
df = pd.DataFrame(np.random.rand(3, len(columns)),)

# %%
df.columns = df.columns.astype(str)

# %%
df = pd.DataFrame(np.random.rand(3, len(columns)), columns=columns)

# get levels 
# nlevels = df.columns.nlevels
def _get_spans(index: Union[pd.Index, pd.MultiIndex]):
    if isinstance(index, pd.MultiIndex):
        levels = np.stack([np.array(value) for value in index]).T
    elif isinstance(index, pd.Index):
        levels = np.array([df.columns])

    for nlevel, level in enumerate(levels):
        # detect where level are discontinuous
        spans = list(np.where(level[1:] != level[:-1])[0])
        # add the first and last cell if necessary
        if 0 not in spans:
            spans.insert(0, -1)
        if len(level) - 1 not in spans:
            spans.append(len(level) - 1)
        # only check if span if larger thant one cell
        for n in np.where(np.diff(list(spans)) > 1)[0]:
            print(spans[n]+1, spans[n+1])
            
_get_spans(df.columns)
# Out:
# 0 14
# 15 29
# 0 4
# 5 9
# 10 14
# 15 19
# 20 24
# 25 29

# %%
if isinstance(df.columns, pd.MultiIndex):
    N = len(df.columns[0])
else:
    N = 1

for level in range(N):  # Iterates over the levels
#     print(level)
    # Find how many segments the MultiIndex has
    if isinstance(df.columns, pd.MultiIndex):
        arr = [df.columns[i][level] for i in range(len(df.columns))]
    else:
        arr = df.columns
        
    print(arr)

    # Holds the starting index of a range of equal values.
    # None means it is not currently in a range of equal values.
    match_start = None

    for col in range(1, len(arr)):  # Iterates over cells in row
        # Check if cell matches cell to its left
        if arr[col] == arr[col - 1]:
            if match_start is None:
                match_start = col - 1
            # If this is the last cell, need to end it
            if col == len(arr) - 1:
                match_end = col
                span_size = match_end - match_start + 1
#                 self.setSpan(level, match_start, 1, span_size)
                print(match_start, match_end)
        else:
            if match_start is not None:
                match_end = col - 1
                span_size = match_end - match_start + 1
#                 self.setSpan(level, match_start, 1, span_size)
                print(match_start, match_end)            
                match_start = None
# Out:
# ['level_0_1', 'level_0_1', 'level_0_0', 'level_0_1', 'level_0_1', 'level_0_1', 'level_0_0', 'level_0_0', 'level_0_0', 'level_0_0', 'level_0_1', 'level_0_0', 'level_0_1', 'level_0_0', 'level_0_0', 'level_0_1', 'level_0_0', 'level_0_0', 'level_0_0', 'level_0_1', 'level_0_0', 'level_0_1', 'level_0_1', 'level_0_1', 'level_0_0', 'level_0_0', 'level_0_0', 'level_0_1', 'level_0_1', 'level_0_1']
# 0 1
# 3 5
# 6 9
# 13 14
# 16 18
# 21 23
# 24 26
# 27 29
# ['level_1_0', 'level_1_2', 'level_1_0', 'level_1_1', 'level_1_2', 'level_1_2', 'level_1_1', 'level_1_0', 'level_1_0', 'level_1_2', 'level_1_2', 'level_1_0', 'level_1_2', 'level_1_0', 'level_1_1', 'level_1_0', 'level_1_0', 'level_1_0', 'level_1_2', 'level_1_1', 'level_1_1', 'level_1_0', 'level_1_2', 'level_1_0', 'level_1_2', 'level_1_1', 'level_1_1', 'level_1_2', 'level_1_2', 'level_1_0']
# 4 5
# 7 8
# 9 10
# 15 17
# 19 20
# 25 26
# 27 28
# ['level_2_0', 'level_2_3', 'level_2_4', 'level_2_2', 'level_2_0', 'level_2_3', 'level_2_0', 'level_2_0', 'level_2_3', 'level_2_0', 'level_2_4', 'level_2_3', 'level_2_1', 'level_2_3', 'level_2_1', 'level_2_3', 'level_2_3', 'level_2_1', 'level_2_0', 'level_2_3', 'level_2_2', 'level_2_3', 'level_2_0', 'level_2_0', 'level_2_4', 'level_2_1', 'level_2_2', 'level_2_3', 'level_2_3', 'level_2_3']
# 6 7
# 15 16
# 22 23
# 27 29

# %% [markdown]
# - attempt to cast to out_type
# - if cast to str, just do
#     na type for str ?
# - if cast to numeric :
#     - pd.to_numeric with coerce to detect potential issue and store them
#     - cast to out_type

# %%
new_data.MatCode == data.MatCode.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-3a74eaebe735> in <module>
# ----> 1 new_data.MatCode == data.MatCode.astype(int)
#
# F:\Python\Miniconda3\envs\QtEnv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# F:\Python\Miniconda3\envs\QtEnv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# F:\Python\Miniconda3\envs\QtEnv\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# F:\Python\Miniconda3\envs\QtEnv\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# F:\Python\Miniconda3\envs\QtEnv\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     972         # work around NumPy brokenness, #1987
#     973         if np.issubdtype(dtype.type, np.integer):
# --> 974             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     975
#     976         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '*'

# %%
new_data
# Out:
#                    NGS MatCode Synchro code       Material name  \
# 0              DTHHA80   14236      PC02768             DTHHA80
# 1     INSOL SULFUR 20H   14417      PC00308    INSOL SULFUR 20H
# 2   RESIN HARD RF ARAL   14164      PC02545  RESIN HARD RF ARAL
# 3        ZINC STEARATE   13995      PC00657       ZINC STEARATE
# 4               AMO040   14021      PC02466             AMO 040
# ..                 ...     ...          ...                 ...
# 57        WAX PARAFFIN   14350      PC00509        WAX PARAFFIN
# 58      PARAFFINE 6470   14351      PC00508      PARAFFINE 6470
# 59                 TMQ   14512      PC00421                 TMQ
# 60                APDS   14470      PC00372                APDS
# 61    RESINE VULC PFBR   14438      PC00344    RESINE VULC PFBR
#
#           Creation date                        Material Type  \
# 0   1991-11-25 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 1   1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 2   1989-07-10 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 3   1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 4   1988-03-18 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# ..                  ...                                  ...
# 57  1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 58  1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 59  1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 60  1978-03-21 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
# 61  1978-02-17 00:00:00  PC-PRODUITS CHIMIQUES SERIES A ET B
#
#                   Product Class              Product Categoy  \
# 0          07-AGENTS DE CUISSON            073-ACCELERATEURS
# 1          07-AGENTS DE CUISSON  072-AGENTS DE VULCANISATION
# 2     08-AGENTS DE RENFORCEMENT                  081-RESINES
# 3             13-AIDE PROCESS 1             136-ANTICOLLANTS
# 4   09-AGENTS DE MISE EN OEUVRE             094-PLASTIFIANTS
# ..                          ...                          ...
# 57      06-AGENTS DE PROTECTION    061-PROTECTEURS PHYSIQUES
# 58      06-AGENTS DE PROTECTION    061-PROTECTEURS PHYSIQUES
# 59      06-AGENTS DE PROTECTION             062-ANTIOXYDANTS
# 60         07-AGENTS DE CUISSON            073-ACCELERATEURS
# 61         07-AGENTS DE CUISSON   076-AGENTS DE RETICULATION
#
#                         Product Type Supplier  ...  Silan's feet  \
# 0          0734-ACCELERATEURS AUTRES        -  ...           NaN
# 1              0722-SOUFRE INSOLUBLE        -  ...           NaN
# 2                       0810-RESINES        -  ...           NaN
# 3   1362-CHARGES MINERALES ET AUTRES        -  ...           NaN
# 4                  0940-PLASTIFIANTS        -  ...           NaN
# ..                               ...      ...  ...           ...
# 57                   0612-PARAFFINES        -  ...           NaN
# 58                   0612-PARAFFINES        -  ...           NaN
# 59                 0620-ANTIOXYDANTS        -  ...           NaN
# 60         0734-ACCELERATEURS AUTRES        -  ...           NaN
# 61    0762-AG DE RETICULATION AUTRES        -  ...           NaN
#
#     Silan's sulfur  Additiv molar mass  Functionality  Purity  Melting point  \
# 0              NaN              288.60            2.0     0.8        >120Â°C
# 1              NaN                 NaN            1.0     0.8         100Â°C
# 2              NaN                 NaN            NaN     NaN            NaN
# 3              NaN                 NaN            NaN     NaN            NaN
# 4              NaN                 NaN            NaN     NaN            NaN
# ..             ...                 ...            ...     ...            ...
# 57             NaN              394.77            NaN    98.0           62.9
# 58             NaN                 NaN            NaN     NaN      66 ou 74?
# 59             NaN                 NaN            NaN     NaN            NaN
# 60             NaN              800.00            2.0    90.0            105
# 61             NaN                 NaN            NaN     NaN            NaN
#
#     Decomposition temperature  Filler amount Filler type  \
# 0                         NaN            NaN         NaN
# 1                         NaN            NaN         NaN
# 2                         NaN            NaN         NaN
# 3                         NaN            NaN         NaN
# 4                         NaN            NaN         NaN
# ..                        ...            ...         ...
# 57                        NaN            NaN         NaN
# 58                        NaN            NaN         NaN
# 59                        NaN            NaN         NaN
# 60                        217            NaN         NaN
# 61                        NaN            NaN         NaN
#
#                                           Commentaire
# 0   Contient 20% de dispersant et liant, RhÃ©nogra...
# 1   contient 20% d'huile.\r\nPolymÃ¨re formÃ© d'at...
# 2                                 non marche courante
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 57  MÃ©lange d'alcanes avec centrage en C28. Point...
# 58  ex: Redezon 200-P, info contradictoire entre c...
# 59                                                NaN
# 60  OligomÃ¨re de polysulfure de tertbutylphenol, ...
# 61     plus tard (uniquement dans membrane de cuisson
#
# [62 rows x 23 columns]

# %% [markdown]
# # Import ?

# %%
import os, glob
from os import walk
from os.path import dirname, join, isfile, basename, isdir, exists, normpath

# %%
basefolder = dirname('./nodes/__init__.py')

# %%
modules = []
for path in glob.glob(join(basefolder, '*')):
    if isfile(path) and not path.endswith('__init__.py'):
        modules.append(basename(path)[:-3])
    elif isdir(path) and exists(join(path, '__init__.py')):
        modules.append(normpath(basename(path)))

# %%
modules
# Out:
# ['cast_columns',
#  'files',
#  'select_columns',
#  'table',
#  'table_concat',
#  'table_describe',
#  'table_melt',
#  'table_merge',
#  'table_pivot',
#  'table_transpose']

# %%
import xml.etree.ElementTree as ET
import re
import pandas as pd

# %%
pd.read_csv('./Stats/Prop_dyn_generation/Models/Latent_description.csv', index_col=[0]).loc['80%']*pd.DataFrame([[0.5]*6])

# %%
def parse_gpx(file):
    tree = ET.parse(file)
    root = tree.getroot()
    try:
        ns = re.match('\{.*\}', root.tag).group(0)
    except:
        ns = ''

    coords = {'lat': [], 'lon': [], 'ele': [], 'time': []}
    # Itère sur chaque point du trajet
    for element in tree.iter(ns+'trkpt'):
        coords['lat'].append(element.attrib['lat'])
        coords['lon'].append(element.attrib['lon'])
        child = element.getchildren()
        for value in child:
            if value.tag == ns+'ele': coords['ele'].append(value.text)
            if value.tag == ns+'time': coords['time'].append(value.text)
                
    return pd.DataFrame(coords).apply(pd.to_numeric, errors='ignore')

# %%
file = 'F:/Downloads/Randonnée/iti0584_crete_du_sancy.gpx'
coords = parse_gpx(file)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
init_notebook_mode(connected=True)
plotly_config = {'showLink': False, 'displaylogo': False, 'modeBarButtonsToRemove': ['sendDataToCloud']}

# %%
data = [dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = coords['lon'],
            lat = coords['lat'],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            )
        )]
layout = dict(
        title = file,
        showlegend = False, 
        geo = dict(
            scope='europe',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )
    
fig = dict( data=data, layout=layout )
iplot(fig, filename='d3-flight-paths', config=plotly_config)

# %%
import pilllow
